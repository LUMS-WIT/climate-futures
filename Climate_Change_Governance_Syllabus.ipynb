# %% [markdown]
# # ENGG562/ENV462 – Climate Change Governance: Science, Data & Models
#
# *Fall 2025–26*
# Prepared by: **Abubakr Muhammad**, **Talha Manzoor**, **Muhammad Awais**
# Date: *June 05, 2025*

# %% [markdown]
# ---
# **How to use this notebook**
# - This notebook is your living course outline & logistics hub.
# - Instructor edits will be synced here; check weekly for updates.
# - Sections are collapsible; use the notebook Outline sidebar (or search) to jump around.
# ---

# %% [markdown]
# ## Course Admin
#
# **Instructor(s):** Abubakr Muhammad · Talha Manzoor · Muhammad Awais
# **Room:** 9-251A
# **Office Hours:** 02:00–04:00 on Wednesdays
# **Email:** abubakr@lums.edu.pk · **Telephone:** 8132
# **Secretary/TA:** TBD · **TA Office Hours:** TBD
# **Course URL:** _(if any)_
#
# **Support Services:** LUMS offers a range of academic and other services to support students. See the complete list at the Support Services hub.
# ↗︎ https://advising.lums.edu.pk/#supportservices

# %% [markdown]
# ## Course Basics
#
# - **Credit Hours:** 3
# - **Lectures per Week:** 2 · **Duration:** 75 minutes
# - **Recitation/Lab (per week):** _N/A specified_
# - **Tutorial (per week):** _N/A specified_
#
# **Course Distribution:** Core / Elective (as per program rules)
# **Open for Student Category:** Open for all student categories

# %% [markdown]
# ## Course Description
#
# **Short version**
# This interdisciplinary course equips students with the tools, models, and frameworks necessary to understand and influence climate, water, energy, and food (WEF) policy through data‑driven systems thinking. It blends technical modeling—such as integrated assessment models and data science—with governance insights into climate adaptation, sustainable agriculture, and infrastructure resilience. Students will engage in scenario‑based planning, explore socio‑technical systems, and work with real‑world case studies, especially from the Indus Basin. The course culminates in a team‑based policy modeling project using local or global datasets.
#
# **Long version**
# This course explores the intersection of climate science, data analytics, and policy governance, equipping students to develop integrated scenarios with state‑of‑the‑art modeling and data‑visualization tools. You’ll begin each week with foundational readings and lectures, then apply those concepts in focused, in‑class case‑study discussions on scenario design, policy interventions, and sectoral analyses—covering mitigation, adaptation, impacts, risk management, and resilience across energy, water, agriculture, and their nexus.
#
# Each module features either a real‑world case study, an invited practitioner seminar, or a field visit to a relevant agency. You might assess a national or provincial climate policy alongside a policymaker, observe disaster‑response operations at an emergency management authority, or discuss grid‑decarbonization strategies with an energy regulator. Weekly assignments will deepen your grasp of core concepts—radiative forcing, carbon budgets, governance instruments, and resilience planning—while small‑group workshops will guide you through building and stress‑testing future trajectories in Integrated Assessment Models and Scenario Explorer.
#
# The semester culminates in a capstone team project: you’ll formulate a governance question, construct a detailed future scenario, and deliver evidence‑based recommendations for reducing climate risk. By the end of the course, you will be adept at translating complex scientific and policy data into clear, academically rigorous strategies—and in drafting a concise policy brief based on your project findings.

# %% [markdown]
# ## Course Prerequisites
#
# **ENGG 562**
# - Graduate standing (any major), _or_ EE/CS/MATH/PHYS/CE undergraduates (min. junior standing), _or_ permission of the instructor.
# - Intermediate experience with data analytics & visualization (Python, MATLAB, R, C/C++).
#
# **ENV 462**
# - SSE undergraduates with a minimum junior standing _or_ by permission of the instructor.
# - Non‑SSE undergraduates with a minimum junior standing **plus** any ENV2xx (or higher) course, _or_ by permission of the instructor.
# - Beginner‑level experience in data analytics & visualization (Excel, Python, R, etc.).

# %% [markdown]
# ## Course Learning Outcomes (CLOs)
#
# - **CLO1:** Explain the physical drivers of climate change and key metrics (radiative forcing, carbon budgets, etc.).
# - **CLO2:** Critically assess climate policy and reporting frameworks (e.g., NDCs, carbon pricing, mitigation/adaptation).
# - **CLO3:** Apply computational modeling and data visualization tools to develop pathways for energy, water, and agriculture systems.
# - **CLO4:** Interpret & communicate complex scenario results to technical and non‑technical audiences.

# %% [markdown]
# ## Grading Breakdown & Policy
#
# > Lectures will be combined across the two course codes; instruments/assessments/grading are **separate**.
#
# | Instrument | Weight |
# |---|---:|
# | Assignment(s) | 20% |
# | Quiz(es) | 10% |
# | Class Participation | 5% |
# | Midterm Examination | 20% |
# | Project | 25% |
# | Final Examination | 20% |
#
# For detailed grading rubrics, see [rubric.ipynb](rubric.ipynb).

# %% [markdown]
# ## Examination Details
#
# ### Midterm
# - **Yes/No:** Yes
# - **Combine/Separate:** Separate
# - **Duration:** 90 minutes
# - **Preferred Date:** Mid‑week
# - **Specifications:** Open‑book and open‑notes
#
# ### Final
# - **Yes/No:** Yes
# - **Combine/Separate:** Separate
# - **Duration:** 3 hours
# - **Specifications:** Open‑book and open‑notes

# %% [markdown]
# ## Campus Supports & Key University Policies
#
# **Campus Supports**
# Students are strongly encouraged to meet instructors and TAs during office hours. Beyond the course, use LUMS resources including CAPS (mental health), LMC (physical health), OAI (accessibility), school advising teams, and online resources.
# ↗︎ Advising resources: https://advising.lums.edu.pk/advising-resources
# ↗︎ Full support services: https://advising.lums.edu.pk/#supportservices
#
# **Academic Honesty / Plagiarism**
# LUMS has zero tolerance for academic dishonesty. Use **similarity@lums.edu.pk** to check essays before submission.
# - Academic & Intellectual Integrity: http://surl.li/gpvwb
# - Understanding & Avoiding Plagiarism: http://surl.li/gpvwo
#
# **Academic Accommodations / Petitions**
# - Long‑term conditions: Office of Accessibility & Inclusion (OAI)
# - Short‑term emergencies: Course instructor or Student Support Services (SSS)
# - Missed Instrument / Petition FAQs: https://rb.gy/8sj1h
#
# **Sexual Harassment Policy**
# LUMS and this class are harassment‑free. Report issues to the instructor(s); for further support or to file a complaint, contact **oai@lums.edu.pk** or **harassment@lums.edu.pk**, or call **042‑35608877**.
# - Harassment, Bullying & Other Interpersonal Misconduct (Presentation): http://surl.li/gpvwt

# %% [markdown]
# ## Course Overview (Dated Schedule)
#
# | Date | Sessions | Module & Topics | In-Class Activities | Instructor / Readings | Homeworks/Assignments | Grading Criteria |
# |---|:---:|---|---|---|---|---|
# | September 02, 2025 | 1 | **Module 1A: Foundations of Climate Science** — Earth's energy balance; Carbon cycle basics; Forcings & Feedbacks; Observational evidence & models | Data visualization exercise: radiative forcing trends | Abubakr Muhammad · Krauss (2021) Ch. 2–5; Schneider (2010) Ch. 1 |  |  |
# | September 04, 2025 | 2 |  |  | Abubakr Muhammad · Krauss (2021) Ch. 2–5; Schneider (2010) Ch. 1 |  |  |
# | September 09, 2025 | 3 |  | Flipped discussion: IPCC report highlights | Abubakr Muhammad · Krauss (2021) Ch. 7–8; Schneider (2010) Ch. 2 |  |  |
# | September 11, 2025 | 4 | **INVITED SPEAKER** — *Fahad Saeed on IPCC & UNFCCC processes* | Provide Dashboard: https://climate-risk-dashboard.iiasa.ac.at/ | Abubakr Muhammad · Krauss (2021) Ch. 7–8; Schneider (2010) Ch. 2 |  |  |
# | September 16, 2025 | 5 | continued |  | Abubakr |  |  |
# | September 18, 2025 | 6 | continued |  | Abubakr |  |  |
# | September 23, 2025 | 7 | **Module 1B: Anthropocene and the Modern Economy** — Energy, Water, AFOLU | Accounting and footprinting exercises | Talha |  |  |
# | September 25, 2025 | 8 | **Module 2A: Climate Reporting Frameworks** — International agreements (UNFCCC, Paris); NDCs | World Bank Climate Change Knowledge Portal | Talha · ETF Reference Manual (UNFCCC); CDKN (2016) |  |  |
# | September 30, 2025 | 9 | **Module 2B: Climate Policy Landscape** — Market instruments (carbon tax, ETS); Mitigation vs adaptation | Discussion: carbon pricing pros/cons | Awais · Dessler (2021) Ch. 11–12 |  |  |
# | October 02, 2025 | 10 | **Module 2B: Climate Policy Landscape** — Market instruments (carbon tax, ETS); Mitigation vs adaptation |  |  |  |  |
# | October 07, 2025 | 11 | **Module 3A: Climate Scenario Development** | En-ROADS | Awais · IPCC AR6 WGI Ch. 1; van Vuuren et al. (2014) | Explore and develop your own scenarios on EN-ROADS simulator |  |
# | October 09, 2025 | 12 | **Module 3A: Socio-economic Development & Climate Change** | https://climatescenarios.org/primer/ |  | Discuss EN-ROADS scenarios in class |  |
# | October 14, 2025 | 13 | **Module 3B: Climate Mitigation** | AR6 Scenario Explorer & Database (IIASA) | Awais · IPCC AR6 WGIII Ch. 3; O’Neill et al. (2017) | Explore AR6 Mitigation scenarios and present a useful summary from results |  |
# | October 16, 2025 | 14 | **Module 3B: Climate Adaptation** | AR6 Scenario Explorer & Database (IIASA) |  |  |  |
# | October 21, 2025 | 15 | **Module 3C: Policy interventions in Integrated Scenarios** — Mitigation & adaptation policies; Policy impacts on emissions & co-benefits | AR6 Scenario Explorer & Database (IIASA) | Awais · IPCC AR6 WGIII Ch. 6; Ch. 13; Riahi et al. (2017) |  |  |
# | October 23, 2025 | 16 | **Midterm** |  |  |  |  |
# | October 28, 2025 | 17 | **Module 3C: Policy interventions in Integrated Scenarios** — Mitigation & adaptation policies; Policy impacts on emissions & co-benefits | MESSAGE | Awais |  |  |
# | October 30, 2025 | 18 |  |  |  |  |  |
# | November 04, 2025 | 19 | **Module 4A: Water Systems** — Water demand & supply modeling; Water Stress; Hydrological; Water Equity at multiple scales | Afreen’s tool ? | Abubakr Muhammad · Schneider (2010) Ch. 6; Papers |  |  |
# | November 06, 2025 | 20 | **INVITED SPEAKER — COP-related event** |  |  |  |  |
# | November 11, 2025 | 21 | **Module 4B: Agriculture Systems** — Hydrological modeling basics; Crop/climate risks | FABLE | Abubakr Muhammad · Schneider (2010) Ch. 10; Papers |  |  |
# | November 13, 2025 | 22 |  |  |  |  |  |
# | November 18, 2025 | 23 | **Case Study** |  |  |  |  |
# | November 20, 2025 | 24 |  |  |  |  |  |
# | November 25, 2025 | 25 | **Module 4C: Water–Energy–Food Nexus** — Coupling sectors; Trade-off analysis | Group exercise: optimize water allocation under energy demand | Talha · Webber (2016) Ch. 2–6; Papers |  |  |
# | November 27, 2025 | 26 |  |  |  |  |  |
# | December 02, 2025 | 27 | **INVITED SPEAKER — IIASA?** |  |  |  |  |
# | December 04, 2025 | 28 | **Capstone Project Presentations** — Project briefs distributed; Team formation & planning | Teams define scope & data needs | Abubakr · Talha · Awais (teams) |  |  |

# %% [markdown]
# ## Textbook(s) & Supplementary Readings
#
# **General Reference & Introduction**
# - Krauss, *The Physics of Climate Change* (2021).
# - Schneider et al., *Climate Change Science and Policy* (2010).
# - Dessler, *Introduction to Modern Climate Change* (2021).
# - Webber, *Thirst for Power* (2016).
#
# **Topical**
# - CDKN (2016). *Planning for NDC Implementation: A Quick‑Start Guide*.
# - UNFCCC (2022). *Reference manual for the Enhanced Transparency Framework under the Paris Agreement*.
# - Published papers and reports (to be provided).
#
# **Self‑Reading**
# - Sachs, *The Age of Sustainable Development* (2015).
# - Smil, *Grand Transitions* (2021).
# - WEF, *Water Security: The Water‑Food‑Energy‑Climate Nexus* (2012).
#
# **Documentaries**
# - _(To be announced during the course)_

# %% [markdown]
# ---
# © LUMS — ENGG562/ENV462 Climate Change Governance: Science, Data & Models
# For questions about this notebook, contact the instructors during office hours.

# %%
# (Optional) Environment check — students can run this to confirm Python & key libs
import sys, platform
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
# Out:
# Python: 3.12.2
# Platform: macOS-15.3.2-x86_64-i386-64bit
